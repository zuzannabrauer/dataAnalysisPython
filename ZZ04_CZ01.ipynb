# %% [markdown]
# # Analiza danych przestrzennych - ćwiczenia laboratoryjne 2023/2024
#
# Ten notatnik zalicza się do grupy zestawów zadań, na podstawie których odbywa się zaliczenie ćwiczeń i podlega zwrotowi do oceny w ustalonym na zajęciach terminie.
#
# Uwagi i wytyczne ogólne dotyczące uzupełniania i oceny notatnika:
# - Podczas wykonywania zadań należy korzystać wyłącznie z pakietów zaimportowanych na początku notatnika oraz z pakietów wchodzących w skład standardowej biblioteki Pythona, które można zaimportować samodzielnie we wskazanej komórce notatnika.
# - Swoje rozwiązania należy wprowadzać wyłącznie w miejce następujących fragmentów kodu:<br/> `# YOUR CODE HERE`<br/> `raise NotImplementedError()`<br/>
# a odpowiedzi tekstowe w komórkach oznaczonych hasłem:<br/>
# `YOUR ANSWER HERE`<br/>
# Nie należy w żaden sposób modyfikować pozostałych fragmentów kodu oraz innych elementów notatnika, w szczególności dodawać lub usuwać komórek oraz zmieniać nazwy pliku.
# - Jeżeli zestaw zadań wymaga skorzystania z fragmentów kodu opracowanego w ramach wcześniejszych zestawów zadań należy je umieścić we wskazanej komórce notatnika.
# - Otrzymywane wyniki i odpowiedzi mają być rezultatem wykonania napisanego kodu, odpowiedzi uzupełniane manualnie nie podlegają ocenie.
# - Zawarte w notatniku automatyczne testy mają charakter poglądowy. Dotyczą one wybranych aspektów zadań i mają na celu wyłapać podstawowe błędy. Przejście przez kod wszystkich testów nie oznacza, że zadanie jest wykonane w całości poprawnie i zostanie ocenione na maksymalną liczbę punktów.
# - Zadania należy wykonać w taki sposób, aby podczas wykonywania kodu nie zostały wyświetlone żadne ostrzeżenia.
# - Zadania, które powodują wyświetlenie komunikatu o błędzie przerywającym wykonywanie kodu nie podlegają ocenie.
#
# Uwagi i wytyczne ogólne dotyczące wizualizacji wyników:
# - Wszystkie wykresy powinny być wykonane w jednolitym, przejrzystym i czytelnym stylu, posiadać odpowiednio dobrane proporcje i zakresy wartości osi.
# - Figury powinny mieć ustawione białe tło, tak, aby niezależnie od ustawień notatnika wszystkie elementy wykresów były dobrze widoczne (domyślnie tło jest przeźroczyste co może powodować problemy w notatnikach z ustawionym ciemnym tłem). Rozmiar poziomy figur nie powinien przekraczać 20 cali.
# - Wykresy oraz ich osie powinny mieć nadane tytuły. Jeżeli w obrębie figury znajduje się więcej niż jeden wykres to figura również powinna mieć nadany tytuł.
#
# Przed odesłaniem zestawu zadań do oceny proszę uzupełnić komórkę z danymi autorów rozwiązania (nazwa zespołu oraz imiona, nazwiska i numery indeksów członków zespołu) oraz upewnić się, że notatnik działa zgodnie z oczekiwaniami. W tym celu należy skorzystać z opcji **Restart Kernel and Run All Cells...** dostępnej na górnej belce notatnika pod symbolem $\blacktriangleright\blacktriangleright$.

# %% [markdown]
# Nazwa zespołu:
# Członkowie:

# %% [markdown]
# ---

# %% [markdown]
# ## Zestaw zadań 4: Wybrane teoretyczne rozkłady prawdopodobieństwa oraz elementy teorii estymacji (Notatnik 1/3)

# %%
import numpy as np
import pandas as pd
import scipy as sp
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Miejsce do importu pakietów wchodzących w skład standardowej biblioteki Pythona oraz ustawienie opcji wykorzystywanych pakietów

# %% [markdown]
# ### Zadanie 1: Podstawowe rozkłady teoretyczne wykorzystywane w statystyce matematycznej [15 pkt]
# Przeanalizuj własności podstawowych teoretycznych rozkładów prawdopodobieństwa wykorzystywane w statystyce matematycznej - rozkładu normalnego, rozkładu t-Studenta, rozkładu chi-kwadrat i rozkładu F Snedecora.

# %% [markdown]
# #### a) Wizualizacja
#
# Zwizualizuj funkcje gęstości prawdopodobieństwa następujących rozkładów teoretycznych:
# - Wykres 1: $N(0, 1)$, $N(0, 0.75)$, $N(0, 1.25)$, $N(-2, 1)$, $N(2, 1)$
# - Wykres 2: $N(0, 1)$, $t(1)$, $t(2)$, $t(5)$, $t(30)$
# - Wykres 3: $\chi^2(1)$, $\chi^2(2)$, $\chi^2(3)$, $\chi^2(5)$, $\chi^2(8)$
# - Wykres 4: $F(10, 1)$, $F(10, 2)$, $F(10, 5)$, $F(10, 10)$, $F(10, 20)$
# - Wykres 5: $F(1, 10)$, $F(2, 10)$, $F(5, 10)$, $F(10, 10)$, $F(20, 10)$
# - Wykres 6: $F(1, 1)$, $F(2, 2)$, $F(5, 5)$, $F(25, 25)$, $F(50, 50)$
#
# gdzie:
# - $N(\mu, \sigma)$ - rozkład normalny o wartości oczekiwanej $\mu$ i odchyleniu standardowym $\sigma$,
# - $t(df)$ - rozkład t-Studenta o $df$ stopniach swobody,
# - $\chi^2(df)$ - rozkład chi-kwadrat o $df$ stopniach swobody,
# - $F(df1, df2)$ - rozkład F Snedecora o $df1$ i $df2$ stopniach swobody.
#
# Zestaw wykresy na pojedynczej figurze (siatka wykresów 2x3). Przygotuj figurę zgodnie z wytycznymi z nagłówka notatnika. Dodatkowo:
# - ustaw identyczne zakresy osi x i y wykresów 1, 2,
# - ustaw identyczne zakresy osi x i y wykresów 4, 5, 6,
# - dobierz zakresy osi x wszystkiech wykresów w taki sposób, aby dobrze widoczny był charakter znajdujących się na nich funkcji,
# - zadbaj o to aby rozkład $N(0, 1)$ na obu wykresach był oznaczony w ten sam sposób (kolor, grubość, styl linii itd.),
# - do każdego wykresów dodaj legendę opisującą widoczne na nim rozkłady i zadbaj o to, aby legenda nie zasłaniała innych elementów wykresu.

# %%
N = [(0,1), (0,0.75), (0,1.25), (-2,1), (2,1)]
T = [1, 2, 5, 30]
X = [1, 2, 3, 5, 8]
F1 = [(10,1), (10,2), (10,5), (10,10), (10,20)]
F2 = [(1,10), (2,10), (5,10), (10,10), (20,10)]
F3 = [(1,1), (2,2), (5,5), (25,25), (50,50)]

title = ["Normal distribution", "T-student distribution", "Chi-2 distribution", 
         "F Snedocer distribution (1)", "F Snedocer distribution (2)", "F Snedocer distribution (3)"]

colors = ['r', 'g', 'b', 'c', 'm', 'y']

fig, ax = plt.subplots(2,3,figsize=(15,10), facecolor='white')
fig.suptitle("Different distributions")

x1=np.linspace(-6,6,100)
x2=np.linspace(-0.01,2,100)
#rozkład normalny 
for i, elem in enumerate(N):
    sns.lineplot(x=x1 ,y=sp.stats.norm.pdf(x1, elem[0], elem[1]), color=colors[i], ax=ax[0,0], label=f"N({elem[0]}, {elem[1]})")
ax[0,0].set_xlim([-5, 5])
ax[0,0].set_ylim([0, 0.65])
#rozkład t-Studenta o 
sns.lineplot(x=x1, y=sp.stats.norm.pdf(x1, 0,1), color=colors[0], ax=ax[0,1], label="N(0,1)") # dodanie N(0,1)
for i, elem in enumerate(T):
    sns.lineplot(x=x1, y=sp.stats.t.pdf(x1, elem), color=colors[i+1], ax=ax[0,1], label=f"t({elem})")
ax[0,1].set_xlim([-5, 5])
ax[0,1].set_ylim([0, 0.65])

#rozkład chi-kwadrat 
for i, elem in enumerate(X):
    sns.lineplot(x=x2, y=sp.stats.chi2.pdf(x2, elem), color=colors[i], ax=ax[0,2], label=f"Chi2({elem})")
ax[0,2].set_xlim([0, 2])
ax[0,2].set_ylim([-0.01, 4])

#rozkład F Snedecora
for i, elem in enumerate(F1):
    sns.lineplot(x=x2, y=sp.stats.f.pdf(x2, elem[0], elem[1]), color=colors[i], ax=ax[1,0], label=f"Snedecor{elem}")
for i, elem in enumerate(F2):
    sns.lineplot(x=x2, y=sp.stats.f.pdf(x2, elem[0], elem[1]), color=colors[i], ax=ax[1,1], label=f"Snedecor{elem}")
for i, elem in enumerate(F3):
    sns.lineplot(x=x2, y=sp.stats.f.pdf(x2, elem[0], elem[1]), color=colors[i], ax=ax[1,2], label=f"Snedecor{elem}")

for i in range (3):
    ax[0,i].set_facecolor("white")
    ax[0,i].set_title(title[i+3])
    ax[0,i].set_xlabel("Value")
    ax[0,i].set_ylabel("Probability density")
    ax[0,i].legend(loc = "upper right", title="Distribution")


for i in range (3):
    ax[1,i].set_xlim([0, 2])
    ax[1,i].set_ylim([-0.01, 4])
    ax[1,i].set_facecolor("white")
    ax[1,i].set_title(title[i+3])
    ax[1,i].set_xlabel("Value")
    ax[1,i].set_ylabel("Probability density")
    ax[1,i].legend(loc = "upper right", title="Distribution")

# %% [markdown]
# #### b) Charakterystyka rozkładów
# Na podstawie przygotowanych wykresów scharakteryzuje opisane rozkłady teoretyczne i odpowiedz na pytanie w jaki sposób zmiana wartości parametrów rozkładów wpływa na położenie i kształt ich funkcji gęstości prawdopodobieństwa.

# %% [markdown]
# Na podstawie przygotowanych wykresów scharakteryzuje opisane rozkłady teoretyczne i odpowiedz na pytanie w jaki sposób zmiana wartości parametrów rozkładów wpływa na położenie i kształt ich funkcji gęstości prawdopodobieństwa.
#
# Rozkład normalny — posiada charakterystyczny dla siebie kształt (kształt dzwonowaty), zmieniając średnią, zmieniamy jego położenie względem osi x. Wykres jest symetryczny względem średniej. Na odchylenie standardowe wpływa na kształt wykresu, im większe std tym wykres robi się niższy i rozciąga się na boki. Ta dystrybucja ma najwyżej położony punkt dla wartości średni w porównaniu z resztą wykresów.
#
# Rozkład t-studenta - posiada podobny kształt do rozkładu normalnego. Wolniej zbiega do bardzo małych wartości niż rozkład normalny. W przypadku wzrostu liczby stopni swobody upodabnia się on coraz bardziej do rozkładu normalnego. Jest symetryczny względem zera.
#
# Rozkład chi-kwadrat — jest on prawostronnie asymetryczny, ma tylko wartości dodatnie (suma kwadratów jest nieujemna, więc jego specyfikacja zapewnia nam nie ujemność). Wraz ze wzrostem liczby stopni swobody, wykres się wypłaszcza.
#
# Rozkład F-Snedecora - Również posiada tylko wartości dodatnie, jest prawostronnie asymetryczny. Wraz ze wzrostem obu stopni swobody, powoli dąży do rozkładu normalnego. Kiedy wzrasta tylko jeden stopień swobody (niezależnie, który) wykresy przesuwają się w prawą stronę i zmieniają się ich wysokości. Przy małej wartości pierwszego ze stopni swobody (wykresy czerwony i zielony), charakterystyka wykresu trochę odbiega od reszty. Widoczny jest gwałtowny spadek wartości, który po chwili się wypłasza.

# %% [markdown]
# ### Zadanie 2: Praca z rozkładami teoretycznymi [10 pkt]

# %% [markdown]
# #### a) Wyliczanie prawdopodobieństw na podstawie wartości
#
# Oblicz i zapisz do zmiennych o podanych nazwach następujące wartości prawdopodobieństwa:
# - `p1` - $P(X < -1.5)$, gdzie $X$ to zmienna losowa ciągła posiadająca rozkład t-Studenta o 10 stopniach swobody - $t(10)$,
# - `p2` - $P(X > 2)$, gdzie $X$ to zmienna losowa ciągła posiadająca rozkład F Snedecora o 5 i 50 stopniach swobody - $F(5, 50)$,
# - `p3` - $P(3 < X < 10)$, gdzie $X$ to zmienna losowa ciągła posiadająca rozkład chi-kwadrat o 4 stopniach swobody - $\chi^2(4)$,
# - `p4` - $P(X < -2.75 | X > 1.5)$, gdzie $X$ to zmienna losowa ciągła posiadająca rozkład normalny o wartości oczewiwanej równej -0.5 i odchyleniu standardowym równym 1.5 - $N(-0.5, 1.5)$,
#
# Każde z rozwiązań zilustruj wykresem zawierającym krzywą gęstości prawdopodobieństwa rozkładu z zaznaczonym kolorem fragmentem pola pod krzywą odpowiadający wyznaczonej wartości prawdopodobieństwa. Przygotuj figurę zgodnie z wytycznymi z nagłówka notatnika. Dodatkowo:
# - ustaw zakres osi x od wartości zmiennej $X$, dla której dystrybuanta analizowanego rozkładu przyjmuje wartość 0.0001 do wartości zmiennej $X$, dla której dystrybuanta analizowanego rozkładu przyjmuje wartość 0.9999,
# - w tytule wykresu zawrzyj uzupełniony wzór na prawdopodobieństwo uzupełniony o wyliczoną wartość prawdopodobieństwa podaną do 4 miejsca po przecinku (np. P(X < -1.5) = x.xxxx, gdzie x.xxxx to obliczona wartość).

# %%
# p1
x1=-1.5
df=10
p1=sp.stats.t.cdf(x1,df)

fig, ax=plt.subplots(figsize=(12,8))
plt.suptitle(f't-Student dla P(X<1.5) = {p1:.4f}')
plt.subplots_adjust(top=0.95)

lower_bound=sp.stats.t.ppf(0.0001, df)
upper_bound=sp.stats.t.ppf(0.9999, df)
x=np.linspace(lower_bound, upper_bound, 1000)
y=sp.stats.t.pdf(x, df)
ax.plot(x,y,color='indigo')

x_fill=np.linspace(min(x),x1,1000)
y_fill=sp.stats.t.pdf(x_fill,df)
ax.fill_between(x_fill, y_fill,color='magenta')

ax.set_xlabel('x')
ax.set_ylabel('gęstość prawdopodobieństwa')
ax.set_xlim(min(x),max(x))
ax.set_ylim(0,max(y)+0.1)
# Out:
# (0.0, 0.4891014320390944)

# %%
# p2
x1=2
df1=5
df2=50
p2=1-sp.stats.f.cdf(x1,df1,df2)

fig, ax=plt.subplots(figsize=(12,8))
plt.suptitle(f'F Snedecora dla P(X>2) = {p2:.4f}')
plt.subplots_adjust(top=0.95)

lower_bound=sp.stats.f.ppf(0.0001,df1,df2)
upper_bound=sp.stats.f.ppf(0.9999,df1,df2)
x=np.linspace(lower_bound, upper_bound, 1000)
y=sp.stats.f.pdf(x,df1,df2)
ax.plot(x,y,color='indigo')

x_fill=np.linspace(x1,max(x),1000)
y_fill=sp.stats.f.pdf(x_fill,df1,df2)
ax.fill_between(x_fill, y_fill,color='magenta')

ax.set_xlabel('x')
ax.set_ylabel('gęstość prawdopodobieństwa')
ax.set_xlim(min(x),max(x))
ax.set_ylim(0,max(y)+0.1)
# Out:
# (0.0, 0.849437666118987)

# %%
# p3
x1=3
x2=10
df=4
p3=sp.stats.chi2.cdf(x2,df)-sp.stats.chi2.cdf(x1,df)

fig, ax=plt.subplots(figsize=(12,8))
plt.suptitle(f'Chi^2(4) dla P(3<X<10) = {p3:.4f}')
plt.subplots_adjust(top=0.95)

lower_bound=sp.stats.chi2.ppf(0.0001,df)
upper_bound=sp.stats.chi2.ppf(0.9999,df)
x=np.linspace(lower_bound, upper_bound, 1000)
y=sp.stats.chi2.pdf(x,df)
ax.plot(x,y,color='indigo')

x_fill=np.linspace(x1,x2,1000)
y_fill=sp.stats.chi2.pdf(x_fill,df)
ax.fill_between(x_fill, y_fill,color='magenta')

ax.set_xlabel('x')
ax.set_ylabel('gęstość prawdopodobieństwa')
ax.set_xlim(min(x),max(x))
ax.set_ylim(0,max(y)+0.1)
# Out:
# (0.0, 0.28393950321014905)

# %%
# p4
x1=-2.75
x2=1.5
mu=-0.5
std=1.5
p4=sp.stats.norm.cdf(x1,mu,std)+1-sp.stats.norm.cdf(x2,mu,std)

fig, ax=plt.subplots(figsize=(12,8))
plt.suptitle(f'Rozkład normalny N(-0.5,1.5) dla P(X<{x1}|X>{x2}) = {p4:.4f}')
plt.subplots_adjust(top=0.95)

lower_bound=sp.stats.norm.ppf(0.0001,mu,std)
upper_bound=sp.stats.norm.ppf(0.9999,mu,std)
x=np.linspace(lower_bound, upper_bound, 1000)
y=sp.stats.norm.pdf(x,mu,std)
ax.plot(x,y,color='indigo')

x_fill_1=np.linspace(min(x),x1,1000)
x_fill_2=np.linspace(x2,max(x),1000)
y_fill_1=sp.stats.norm.pdf(x_fill_1,mu,std)
y_fill_2=sp.stats.norm.pdf(x_fill_2,mu,std)
ax.fill_between(x_fill_1, y_fill_1,color='magenta')
ax.fill_between(x_fill_2, y_fill_2,color='magenta')

ax.set_xlabel('x')
ax.set_ylabel('gęstość prawdopodobieństwa')
ax.set_xlim(min(x),max(x))
ax.set_ylim(0,max(y)+0.1)
# Out:
# (0.0, 0.3659596773219328)

# %%
### Komórka testowa
assert np.isclose(p1, 0.08225366322272008)
assert np.isclose(p2, 0.0947529020300999)
assert np.isclose(p3, 0.5173977183765621)
assert np.isclose(p4, 0.15801842099472596)

# %% [markdown]
# #### b) Wyliczanie wartości na podstawie prawdopodobieństw
#
# Rozwiąż i zapisz do zmiennych o podanych nazwach rozwiązania następujących równań:
# - `s1` - $P(X < s) = 0.25$, gdzie X to zmienna losowa ciągła posiadająca rozkład chi-kwadrat o 5 stopniach swobody - $\chi^2(5)$,
# - `s2` - $P(X > s) = 0.15$, gdzie X to zmienna losowa ciągła posiadająca rozkład F Snedecora o 5 i 20 stopniach swobody - $F(5, 20)$,
# - `s3` - $P(-1.25 < X < s) = 0.35$, gdzie x to zmienna losowa ciągła posiadająca rozkład normalny o wartości oczewiwanej równej -0.4 i odchyleniu standardowym równym 0.75 - $N(-0.4, 0.75)$,
#
# Każde z rozwiązań zilustruj wykresem zawierającym krzywą gęstości prawdopodobieństwa rozkładu z zaznaczonym kolorem fragmentem pola pod krzywą odpowiadający wartości prawdopodobieństwa określonej przez rozwiązywane równanie. Przygotuj figurę zgodnie z wytycznymi z nagłówka notatnika. Dodatkowo:
# - ustaw zakres osi x od wartości zmiennej $X$, dla której dystrybuanta analizowanego rozkładu przyjmuje wartość 0.0001 do wartości zmiennej $X$, dla której dystrybuanta analizowanego rozkładu przyjmuje wartość 0.9999,
# - oznacz krawędź obszaru, na której znajduje się wyznaczona wartość $s$ linią w wyróżniającym się kolorze,
# - w tytule wykresu zawrzyj uzupełniony wzór na prawdopodobieństwo uzupełniony o wyliczoną wartość zmiennej $X$ podaną do 4 miejsca po przecinku (np. P(X < s.ssss) = 0.25, gdzie s.ssss to obliczona wartość).

# %%
# s1
df=5
s1=sp.stats.chi2.ppf(0.25,df)

fig, ax=plt.subplots(figsize=(12,8))
plt.suptitle(f'Chi^2(5) dla P(X<{s1:.4f}) = 0.25')
plt.subplots_adjust(top=0.95)

lower_bound=sp.stats.chi2.ppf(0.0001, df)
upper_bound=sp.stats.chi2.ppf(0.9999, df)
x=np.linspace(lower_bound, upper_bound, 1000)
y=sp.stats.chi2.pdf(x, df)
ax.plot(x,y,color='indigo')

x_fill=np.linspace(min(x),s1,1000)
y_fill=sp.stats.chi2.pdf(x_fill,df)
ax.fill_between(x_fill, y_fill,color='pink')
ax.axvline(x=s1, ymin=0, ymax=sp.stats.chi2.pdf(s1, df)/(max(y)+0.1),color='magenta',linewidth=2)
ax.set_xlabel('x')
ax.set_ylabel('gęstość prawdopodobieństwa')
ax.set_xlim(min(x),max(x))
ax.set_ylim(0,max(y)+0.1)
# Out:
# (0.0, 0.25417887637455067)

# %%
# s2
df1=5
df2=20
s2=sp.stats.f.ppf(1-0.15,df1,df2)

fig, ax=plt.subplots(figsize=(12,8))
plt.suptitle(f'F Snedecora dla P(X>{s2:.4f}) = 0.15')
plt.subplots_adjust(top=0.95)

lower_bound=sp.stats.f.ppf(0.0001,df1,df2)
upper_bound=sp.stats.f.ppf(0.9999,df1,df2)
x=np.linspace(lower_bound, upper_bound, 1000)
y=sp.stats.f.pdf(x,df1,df2)
ax.plot(x,y,color='indigo')

x_fill=np.linspace(s2,max(x),1000)
y_fill=sp.stats.f.pdf(x_fill,df1,df2)
ax.fill_between(x_fill, y_fill,color='pink')
ax.axvline(x=s2, ymin=0, ymax=sp.stats.f.pdf(s2,df1,df2)/(max(y)+0.1),color='magenta',linewidth=2)

ax.set_xlabel('x')
ax.set_ylabel('gęstość prawdopodobieństwa')
ax.set_xlim(min(x),max(x))
ax.set_ylim(0,max(y)+0.1)
# Out:
# (0.0, 0.8224784898360399)

# %%
# s3
mu=-0.4
std=0.75

cdf3=sp.stats.norm.cdf(-1.25,mu,std)
s3=sp.stats.norm.ppf(cdf3+0.35,mu,std)

fig, ax=plt.subplots(figsize=(12,8))
plt.suptitle(f'Chi^2(4) dla P(-1.25<X<{s3:.4f}) = 0.35')
plt.subplots_adjust(top=0.95)

lower_bound=sp.stats.norm.ppf(0.0001,mu,std)
upper_bound=sp.stats.norm.ppf(0.9999,mu,std)
x=np.linspace(lower_bound, upper_bound, 1000)
y=sp.stats.norm.pdf(x,mu,std)
ax.plot(x,y,color='indigo')

x_fill=np.linspace(-1.25,s3,1000)
y_fill=sp.stats.norm.pdf(x_fill,mu,std)
ax.fill_between(x_fill, y_fill,color='pink')
ax.axvline(x=s3, ymin=0, ymax=sp.stats.norm.pdf(s3,mu,std)/(max(y)+0.1),color='magenta',linewidth=2)

ax.set_xlabel('x')
ax.set_ylabel('gęstość prawdopodobieństwa')
ax.set_xlim(min(x),max(x))
ax.set_ylim(0,max(y)+0.1)
# Out:
# -0.4403690254222098

# %%
### Komórka testowa
assert np.isclose(s1, 2.6746028094321637)
assert np.isclose(s2, 1.843305229426929)
assert np.isclose(s3,-0.4403690254222098)
